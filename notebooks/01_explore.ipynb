# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
import os
import librosa
import numpy as np
from collections import Counter

DATA_DIR = "../data/raw"

labels = []
durations = []

for label in os.listdir(DATA_DIR):
    label_path = os.path.join(DATA_DIR, label)
    if not os.path.isdir(label_path):
        continue

    for file in os.listdir(label_path):
        if file.lower().endswith(".wav"):
            file_path = os.path.join(label_path, file)
            y, sr = librosa.load(file_path, sr=None)
            durations.append(librosa.get_duration(y=y, sr=sr))
            labels.append(label)

print("Total samples:", len(labels))
print("Class distribution:", Counter(labels))
print("Avg duration:", round(np.mean(durations), 2))
print("Min duration:", round(np.min(durations), 2))
print("Max duration:", round(np.max(durations), 2))
# Out:
# Total samples: 457
# Class distribution: Counter({'hungry': 382, 'discomfort': 27, 'tired': 24, 'belly_pain': 16, 'burping': 8})
# Avg duration: 6.92
# Min duration: 6.52
# Max duration: 7.06

# %%
from src.feature_extraction import extract_features
import os

sample = "../data/raw/hungry"
sample_file = os.path.join(sample, os.listdir(sample)[0])

features = extract_features(sample_file)
print(features.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.feature_extraction import extract_features
#       2 import os
#       4 sample = "../data/raw/hungry"
#
# ImportError: cannot import name 'extract_features' from 'src.feature_extraction' (d:\CODING\CryClassifier\baby_cry_project\src\feature_extraction.py)

# %%
import src.feature_extraction as fe
print(dir(fe))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))

import src.feature_extraction as fe
print(dir(fe))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
from src.feature_extraction import extract_features
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.feature_extraction import extract_features
#
# ModuleNotFoundError: No module named 'src'
